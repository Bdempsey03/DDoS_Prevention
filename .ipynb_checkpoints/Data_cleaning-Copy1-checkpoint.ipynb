# %%
import pandas as pd
col_names = [
'Inbound','ACK Flag Count', 'Timestamp', 'Destination IP', 'Source Port', 'Min Packet Length','Destination IP', 'Protocol',
'Avg Fwd Segment Size', 'Fwd Packet Length Min', 'Packet Length Min', 'Fwd Packet Length mean', 'Fwd Packet Length Max', 'Max Packet Length'
, 'Average Packet Size', 'CWE Flag Count']
UDP = pd.read_csv("DrDoS_UDP.csv", header = 0, names = col_names, dtype = 'unicode')
# Out:
#                                                                   Unnamed: 0  \
# 101418 172.16.0.5-192.168.50.1-43443-6652-17  172.16.0.5 43443  192.168.50.1
# 21564  172.16.0.5-192.168.50.1-54741-9712-17  172.16.0.5 54741  192.168.50.1
# 23389  172.16.0.5-192.168.50.1-56589-4680-17  172.16.0.5 56589  192.168.50.1
# 48872  172.16.0.5-192.168.50.1-40233-2644-17  172.16.0.5 40233  192.168.50.1
# 80354  172.16.0.5-192.168.50.1-33989-16901-17 172.16.0.5 33989  192.168.50.1
#
#                                                                Source IP  \
# 101418 172.16.0.5-192.168.50.1-43443-6652-17  172.16.0.5 43443      6652
# 21564  172.16.0.5-192.168.50.1-54741-9712-17  172.16.0.5 54741      9712
# 23389  172.16.0.5-192.168.50.1-56589-4680-17  172.16.0.5 56589      4680
# 48872  172.16.0.5-192.168.50.1-40233-2644-17  172.16.0.5 40233      2644
# 80354  172.16.0.5-192.168.50.1-33989-16901-17 172.16.0.5 33989     16901
#
# ...

# %%
num_of_rows = len(UDP['Destination IP'])

# for x in range (0, num_of_rows):
#     UDP.loc[x, 'Source IP'] = UDP['Source IP'][x].replace(".","")
#     if x%1000000 == 0:
#         print( str((round(x/len(UDP['Source IP']),3)*100)) +"% completed Source IP")

# %%
for x in range (0, num_of_rows):
    UDP.loc[x, 'Destination IP'] = UDP['Destination IP'][x].replace(".","")
    if x%1000000 == 0:
        print( str((round(x/len(UDP['Destination IP']),3)*100)) +"% completed Destination IP")
# Out:
# C:\Users\benmd\AppData\Local\Temp\ipykernel_6408\775687987.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   UDP.loc[x, 'Destination IP'] = UDP['Destination IP'][x].replace(".","")
# C:\Users\benmd\AppData\Local\Temp\ipykernel_6408\775687987.py:2: PerformanceWarning: indexing past lexsort depth may impact performance.
#   UDP.loc[x, 'Destination IP'] = UDP['Destination IP'][x].replace(".","")
# 0.0% completed Destination IP
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python312\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
# ...

# %%
map = {'BENIGN': 0, 'DrDoS_UDP': 1}
UDP.replace(map, inplace=True)
# for x in range(0, num_of_rows):
#     if x%100000 == 0:
#         print( str((round(x/len(UDP['Destination IP']),3)*100)) +"% completed Label")
    
print(UDP['Timestamp'][1])
UDP['Timestamp'] = pd.to_datetime(UDP['Timestamp']).astype('int64')/10**9

# %%
UDP

# %%
#drop all zero columns
UDP = UDP.replace('Infinity', None)
UDP = UDP.dropna()
UDP = UDP.loc[(UDP!=0).any(axis=1)]
UDP['Source IP'], UDP['Destination IP'] = UDP['Source IP'].astype('int64'), UDP['Destination IP'].astype('int64')
UDP[col_names] = UDP[col_names].astype('float64')
UDP.head()

# %%
UDP = UDP['Inbound','ACK Flag Count', 'Timestamp', 'Destination IP', 'Source Port', 'Min Packet Length','Destination IP', 'Protocol',
'Avg Fwd Segment Size', 'Fwd Packet Length Min', 'Packet Length Min', 'Fwd Packet Length mean', 'Fwd Packet Length Max', 'Max Packet Length'
, 'Average Packet Size', 'CWE Flag Count']

# %%
UDP.to_csv("cleaned_DrDoS_UDP.csv")
